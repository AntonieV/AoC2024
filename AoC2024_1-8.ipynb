# %%
### https://adventofcode.com/2024

import re


DAY = 1

def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
def parse_input(_data):
    list1, list2 = [], []
    for line in _data:
        l1, l2 = re.split('\s+', line)
        list1.append(int(l1))
        list2.append(int(l2))
    return sorted(list1), sorted(list2)
    

def get_solution_1(list1, list2):
    return sum([abs(list1[i] - list2[i]) for i in range(len(list1))])
        
    
def get_solution_2(list1, list2):
    list1 = list(set(list1))
    return sum([item * list2.count(item) for item in list1])



file = f"data/day_{DAY}.txt"


data = read_file(file)
list_1, list_2 = parse_input(data)
solution_1 = get_solution_1(list_1, list_2)

solution_2 = get_solution_2(list_1, list_2)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)

# Day 1 - Solution 1: 936063
# Day 1 - Solution 2: 23150395
# Out:
# Day 1 - Solution 1: 936063
# Day 1 - Solution 2: 23150395

# %%
### https://adventofcode.com/2024

DAY = 2


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 2 - Solution 1: None
# Day 2 - Solution 2: None

# %%
### https://adventofcode.com/2024

DAY = 3


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 3 - Solution 1: None
# Day 3 - Solution 2: None

# %%
### https://adventofcode.com/2024

DAY = 4


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 4 - Solution 1: None
# Day 4 - Solution 2: None

# %%
### https://adventofcode.com/2024

DAY = 5


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 5 - Solution 1: None
# Day 5 - Solution 2: None

# %%
### https://adventofcode.com/2024

DAY = 6


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 6 - Solution 1: None
# Day 6 - Solution 2: None

# %%
### https://adventofcode.com/2024

DAY = 7


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 7 - Solution 1: None
# Day 7 - Solution 2: None

# %%
### https://adventofcode.com/2024

DAY = 8


def read_file(file_name):
    with open(file_name, 'r') as f_in:
        return list(filter(None, [line.strip() for line in f_in.readlines()]))
    
    
def parse_input_1(_data):
    pass
    
    
def parse_input_2(_data):
    pass


def get_solution_1(data):
    pass
        
    
def get_solution_2(data):
    pass




file_1 = f"data/day_{DAY}.txt"


data = read_file(file)
data = parse_input_1(data)
solution_1 = get_solution_1(data)

data = read_file(file)
data = parse_input_2(data)
solution_2 = get_solution_2(data)

print(f"Day {DAY} - Solution 1:", solution_1)
print(f"Day {DAY} - Solution 2:", solution_2)
# Out:
# Day 8 - Solution 1: None
# Day 8 - Solution 2: None
